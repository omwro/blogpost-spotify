# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px

# %%
# Meest geluisterde genre in NL
# Meest geluisterde liedjes in NL
# Meest geluisterde liedjes buiten NL
# Trend in loudness/tempo per jaar 
# Meest beroemde podcast talen/landen

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

birdy_uri = 'spotify:playlist:37i9dQZEVXbMDoHDwVN2tF'
results = sp.playlist(birdy_uri)
print(results)
# Out:
# {'collaborative': False, 'description': 'Your daily update of the most played tracks right now - Global.', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF'}, 'followers': {'href': None, 'total': 16339839}, 'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF?additional_types=track', 'id': '37i9dQZEVXbMDoHDwVN2tF', 'images': [{'height': None, 'url': 'https://charts-images.scdn.co/assets/locale_en/regional/daily/region_global_large.jpg', 'width': None}], 'name': 'Top 50 - Global', 'owner': {'display_name': 'Spotify', 'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'}, 'href': 'https://api.spotify.com/v1/users/spotify', 'id': 'spotify', 'type': 'user', 'uri': 'spotify:user:spotify'}, 'primary_color': None, 'public': True, 'snapshot_id': 'Njg2MjI1ODQ4LDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDY1NmU=', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF/tracks?offset=0&limit=100&ad
# ...

# %%
df_spotify = pd.read_csv('Spotify-2000.csv')
print(df_spotify)
# Out:
#       Index                   Title                    Artist  \
# 0         1                 Sunrise               Norah Jones
# 1         2             Black Night               Deep Purple
# 2         3          Clint Eastwood                  Gorillaz
# 3         4           The Pretender              Foo Fighters
# 4         5  Waitin' On A Sunny Day         Bruce Springsteen
# ...     ...                     ...                       ...
# 1989   1990        Heartbreak Hotel             Elvis Presley
# 1990   1991               Hound Dog             Elvis Presley
# 1991   1992         Johnny B. Goode               Chuck Berry
# 1992   1993               Take Five  The Dave Brubeck Quartet
# 1993   1994          Blueberry Hill               Fats Domino
#
#                 Top Genre  Year  Beats Per Minute (BPM)  Energy  Danceability  \
# 0         adult standards  2004                     157      30            53
# ...

# %%
print(df_spotify['Top Genre'])
# Out:
# 0           adult standards
# 1                album rock
# 2       alternative hip hop
# 3         alternative metal
# 4              classic rock
#                ...
# 1989        adult standards
# 1990        adult standards
# 1991             blues rock
# 1992                  bebop
# 1993        adult standards
# Name: Top Genre, Length: 1994, dtype: object

# %%
print(df_spotify['Top Genre'].describe())
# Out:
# count           1994
# unique           149
# top       album rock
# freq             413
# Name: Top Genre, dtype: object

# %%
df_spotify.value_counts(["Top Genre"])[df_spotify.value_counts(["Top Genre"]) >= 5]
# Out:
# Top Genre
# album rock              413
# adult standards         123
# dutch pop                88
# alternative rock         86
# dance pop                83
# dutch indie              75
# alternative metal        70
# dance rock               52
# dutch cabaret            51
# classic rock             51
# glam rock                49
# modern rock              49
# pop                      47
# art rock                 40
# permanent wave           38
# british invasion         36
# irish rock               34
# british soul             31
# europop                  27
# classic uk pop           22
# disco                    18
# dutch rock               18
# glam metal               17
# neo mellow               17
# blues rock               15
# alternative dance        15
# art pop                  14
# dutch hip hop            13
# funk                     13
# dutch americana          12
# britpop                  11
# classic soul             11
# ...

# %%
#df_spotify['Top Genre'] = None
# ROCK
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "rock" if "album rock" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "rock" if "alternative rock" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "rock" if "classic rock" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "rock" if "glam rock" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "rock" if "modern rock" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "rock" if "art rock" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "rock" if "irish rock" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "rock" if "dutch rock" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "rock" if "blues rock" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "rock" if "belgian rock" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "rock" if "alternative pop rock" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "rock" if "modern folk rock" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "rock" if "celtic rock" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)

# POP
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "pop" if "dutch pop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "pop" if "dance pop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "pop" if "pop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "pop" if "art pop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "pop" if "britpop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "pop" if "german pop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "pop" if "australian pop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "pop" if "chamber pop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "pop" if "baroque pop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "pop" if "brill building pop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "pop" if "canadian pop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "pop" if "classic country pop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)

# HIPHOP
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "hip-hop" if "dutch hip hop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "hip-hop" if "alternative hip hop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "hip-hop" if "detroit hip hop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "hip-hop" if "east coast hip hop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "hip-hop" if "atl hip hop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)
#df_spotify['Top Genre'] = df_spotify.apply(lambda genre: "hip-hop" if "dutch hip hop" in df_spotify['Top Genre'] is None else df_spotify['Top Genre'], axis = 1)

# %%
print(df_spotify['Top Genre'].unique())
df_spotify['Genre category'] = None

# ROCK
df_spotify['Genre category'] = df_spotify.apply(lambda song: "rock" if "rock" in song['Top Genre'] else song['Top Genre'], axis = 1)

# POP
df_spotify['Genre category'] = df_spotify.apply(lambda song: "pop" if "pop" in song['Top Genre'] else song['Top Genre'], axis = 1)

# HIP-HOP
df_spotify['Genre category'] = df_spotify.apply(lambda song: "hip-hop" if "hip hop" in song['Top Genre'] else song['Top Genre'], axis = 1)



print(df_spotify)
# Out:
# ['adult standards' 'album rock' 'alternative hip hop' 'alternative metal'
#  'classic rock' 'alternative pop rock' 'pop' 'modern rock'
#  'detroit hip hop' 'alternative rock' 'dutch indie' 'garage rock'
#  'dutch cabaret' 'permanent wave' 'classic uk pop' 'dance pop'
#  'modern folk rock' 'dutch pop' 'dutch americana' 'alternative dance'
#  'german pop' 'afropop' 'british soul' 'irish rock' 'disco' 'big room'
#  'art rock' 'danish pop rock' 'neo mellow' 'britpop' 'boy band'
#  'carnaval limburg' 'arkansas country' 'latin alternative' 'british folk'
#  'celtic' 'chanson' 'celtic rock' 'hip pop' 'east coast hip hop'
#  'dutch rock' 'blues rock' 'electro' 'australian pop' 'belgian rock'
#  'downtempo' 'reggae fusion' 'british invasion' 'finnish metal'
#  'canadian pop' 'bow pop' 'dutch hip hop' 'dutch metal' 'soft rock'
#  'acoustic pop' 'acid jazz' 'dutch prog' 'candy pop' 'operatic pop'
#  'trance' 'scottish singer-songwriter' 'mellow gold' 'alternative pop'
# ...

# %%
print(df_spotify['Genre category'])
# Out:
# 0         adult standards
# 1              album rock
# 2                 hip-hop
# 3       alternative metal
# 4            classic rock
#               ...
# 1989      adult standards
# 1990      adult standards
# 1991           blues rock
# 1992                bebop
# 1993      adult standards
# Name: Genre category, Length: 1994, dtype: object

# %%
df_spotify['Genre category'] = None

# ROCK
df_spotify['Genre category'] = df_spotify.apply(lambda song: "rock" if "rock" in song['Top Genre'] else song['Genre category'], axis = 1)
df_spotify['Genre category'] = df_spotify.apply(lambda song: "rock" if "indie" in song['Top Genre'] else song['Genre category'], axis = 1)

# POP
df_spotify['Genre category'] = df_spotify.apply(lambda song: "pop" if "pop" in song['Top Genre'] else song['Genre category'], axis = 1)
df_spotify['Genre category'] = df_spotify.apply(lambda song: "pop" if "adult standards" in song['Top Genre'] else song['Genre category'], axis = 1)
df_spotify['Genre category'] = df_spotify.apply(lambda song: "pop" if "permanent wave" in song['Top Genre'] else song['Genre category'], axis = 1)
df_spotify['Genre category'] = df_spotify.apply(lambda song: "pop" if "boy band" in song['Top Genre'] else song['Genre category'], axis = 1)
df_spotify['Genre category'] = df_spotify.apply(lambda song: "pop" if "neo mellow" in song['Top Genre'] else song['Genre category'], axis = 1)


# HIP-HOP
df_spotify['Genre category'] = df_spotify.apply(lambda song: "hip-hop" if "hip hop" in song['Top Genre'] else song['Genre category'], axis = 1)
df_spotify['Genre category'] = df_spotify.apply(lambda song: "hip-hop" if "g funk" in song['Top Genre'] else song['Genre category'], axis = 1)

# JAZZ
df_spotify['Genre category'] = df_spotify.apply(lambda song: "jazz" if "jazz" in song['Top Genre'] else song['Genre category'], axis = 1)
df_spotify['Genre category'] = df_spotify.apply(lambda song: "jazz" if "bebop" in song['Top Genre'] else song['Genre category'], axis = 1)
df_spotify['Genre category'] = df_spotify.apply(lambda song: "jazz" if "dutch cabaret" in song['Top Genre'] else song['Genre category'], axis = 1)
df_spotify['Genre category'] = df_spotify.apply(lambda song: "jazz" if "soul" in song['Top Genre'] else song['Genre category'], axis = 1)
df_spotify['Genre category'] = df_spotify.apply(lambda song: "jazz" if "disco" in song['Top Genre'] else song['Genre category'], axis = 1)

# METAL
df_spotify['Genre category'] = df_spotify.apply(lambda song: "metal" if "metal" in song['Top Genre'] else song['Genre category'], axis = 1)

# RAP
df_spotify['Genre category'] = df_spotify.apply(lambda song: "rap" if "rap" in song['Top Genre'] else song['Genre category'], axis = 1)

# CLASSIC
df_spotify['Genre category'] = df_spotify.apply(lambda song: "classical" if "classic" in song['Top Genre'] else song['Genre category'], axis = 1)

# BLUES
df_spotify['Genre category'] = df_spotify.apply(lambda song: "blues" if "folk" in song['Top Genre'] else song['Genre category'], axis = 1)
df_spotify['Genre category'] = df_spotify.apply(lambda song: "blues" if "americana" in song['Top Genre'] else song['Genre category'], axis = 1)

# HOUSE
df_spotify['Genre category'] = df_spotify.apply(lambda song: "house" if "big room" in song['Top Genre'] else song['Genre category'], axis = 1)
df_spotify['Genre category'] = df_spotify.apply(lambda song: "house" if "house" in song['Top Genre'] else song['Genre category'], axis = 1)
df_spotify['Genre category'] = df_spotify.apply(lambda song: "house" if "trance" in song['Top Genre'] else song['Genre category'], axis = 1)
df_spotify['Genre category'] = df_spotify.apply(lambda song: "house" if "edm" in song['Top Genre'] else song['Genre category'], axis = 1)

# %%
# OTHER
df_spotify['Genre category'] = df_spotify.apply(lambda song: "other" if song['Genre category'] is None else song['Genre category'], axis = 1)

# %%
print(df_spotify['Genre category'].unique())
# Out:
# ['pop' 'rock' 'hip-hop' 'metal' 'classical' 'jazz' 'blues' 'other' 'house'
#  'rap']

# %%
print(df_spotify['Genre category'])
# Out:
# 0             pop
# 1            rock
# 2         hip-hop
# 3           metal
# 4       classical
#           ...
# 1989          pop
# 1990          pop
# 1991         rock
# 1992         jazz
# 1993          pop
# Name: Genre category, Length: 1994, dtype: object

# %%
list(df_spotify['Genre category'].unique())
# Out:
# ['pop',
#  'rock',
#  'hip-hop',
#  'metal',
#  'classical',
#  'jazz',
#  'blues',
#  'other',
#  'house',
#  'rap']

# %%
#fig = px.box(data_frame=df_spotify, x='Genre category', y='Popularity', color='Genre category',
 #           color_discrete_map = {'pop':'rgb(227, 119, 194)', 'rock':'rgb(127, 127, 127)', 'hip-hop':'rgb(255, 127, 14)',
  #                              'metal':'rgb(150, 190, 170)', 'classical':'rgb(255, 64, 64)', 'jazz':'rgb(100, 149, 237)',
   #                              'blues':'rgb(191, 62, 255)', 'house':'rgb(255, 215, 0)', 'rap':'rgb(3, 3, 3)', 'other':'rgb(192, 255, 62)'})

fig = go.Figure()

features = ['Popularity', 'Loudness (dB)', 'Danceability', 'Valence', 'Speechiness', 'Energy']


color = {'pop':'rgb(227, 119, 194)', 'rock':'rgb(127, 127, 127)', 'hip-hop':'rgb(255, 127, 14)',
                       'metal':'rgb(150, 190, 170)', 'classical':'rgb(255, 64, 64)', 'jazz':'rgb(100, 149, 237)',
                     'blues':'rgb(191, 62, 255)', 'house':'rgb(255, 215, 0)', 'rap':'rgb(3, 3, 3)', 'other':'rgb(192, 255, 62)'}


for features in features :
    genres = df_spotify[features]
    fig.add_trace(go.Box(x=df_spotify['Genre category'], y=genres, name=features, fillcolor=color))
               
        
dropdown_spotify = [
    {'label':'Popularity', 'method':'update', 'args':[{'visible':[True, False, False, False, False, False]},
                                                       {'title':'Popularity'}]},
    {'label':'Loudness (dB)', 'method':'update', 'args':[{'visible':[False, True, False, False, False, False]},
                                                       {'title':'Loudness (dB)'}]},
    {'label':'Danceability', 'method':'update', 'args':[{'visible':[False, False, True, False, False, False]},
                                                       {'title':'Danceability'}]},
    {'label':'Valence', 'method':'update', 'args':[{'visible':[False, False, False, True, False, False]},
                                                       {'title':'Valence'}]},
    {'label':'Speechiness', 'method':'update', 'args':[{'visible':[False, False, False, False, True, False]},
                                                       {'title':'Speechiness'}]},
    {'label':'Energy', 'method':'update', 'args':[{'visible':[False, False, False, False, False, True]},
                                                       {'title':'Energy'}]},
]  
    
fig.update_layout({'updatemenus':[{'type':'dropdown', 'x':1.2, 'y':0.2, 'showactive': True, 'active':0, 'buttons':dropdown_spotify}]})

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-be3ed23c9244> in <module>
#      16 for features in features :
#      17     genres = df_spotify[features]
# ---> 18     fig.add_trace(go.Box(x=df_spotify['Genre category'], y=genres, name=features, fillcolor=color))
#      19
#      20
#
# ...

# %%
# Out:
# rgb(227, 119, 194)
